# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
sns.set(style='ticks', palette='Set2')
sns.despine()

# %%
ScoredMasterCSVtest = pd.read_csv('C:/Users/Jonathan/Documents/GitHub/ConservativeSentimentAnalysis/master_scored_queried.csv')
# Out:
# C:\Users\Jonathan\Miniconda3\envs\ConservativeSentimentAnalysis\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (11,12,35) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# reverse one-hot encoding
ScoredMasterCSVtest['Sex'] = (ScoredMasterCSVtest.iloc[:, 41:] == 1).idxmax(1)

# actuals and predicted to one column
df = ScoredMasterCSVtest.melt(id_vars ='Sex', value_vars=['Sentiment Score'])

print(df.head(5))

sns.boxplot(x='Sex', y='value', data=df)
plt.show()

sns.histplot(data=df, x='value', hue="Sex", bins = 40)
#sns.histplot(data=df, x='value', hue="Sex", bins = 40, kde=True)
plt.show()
#sns.scatterplot(x='Sex', y='value', data=df)
# Out:
#    Sex         variable   value
# 0  she  Sentiment Score  0.5927
# 1  she  Sentiment Score  0.5927
# 2  she  Sentiment Score -0.5423
# 3  she  Sentiment Score  0.5927
# 4  she  Sentiment Score -0.5423
